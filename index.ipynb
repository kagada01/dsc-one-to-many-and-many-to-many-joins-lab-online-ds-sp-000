# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge of one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# * Explain one-to-many and many-to-many joins as well as implications for the size of query results
# * Query data using one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a DataFrame with all of the employees including their first name and last name along with the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
cur.execute("""SELECT *
            FROM employees
            JOIN offices
            USING(officeCode)
            ORDER BY firstName ASC, lastName ASC
            ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    employeeNumber lastName firstName extension                         email  \
# 0            1611   Fixter      Andy      x101  afixter@classicmodelcars.com
# 1            1143      Bow   Anthony     x5428     abow@classicmodelcars.com
# 2            1504    Jones     Barry      x102   bjones@classicmodelcars.com
# 3            1002   Murphy     Diane     x5800  dmurphy@classicmodelcars.com
# 4            1286    Tseng  Foon Yue     x2248   ftseng@classicmodelcars.com
#
#    officeCode reportsTo            jobTitle           city             phone  \
# 0           6      1088           Sales Rep         Sydney   +61 2 9264 2451
# 1           1      1056  Sales Manager (NA)  San Francisco   +1 650 219 4782
# 2           7      1102           Sales Rep         London  +44 20 7877 2041
# 3           1                     President  San Francisco   +1 650 219 4782
# 4           3      1143           Sales Rep            NYC   +1 212 555 3000
#
#             addressLine1 addressLine2 state    country postalCode territory
# 0  5-11 Wentworth Avenue     Floor #2        Australia   NSW 2010      APAC
# 1      100 Market Street    Suite 300    CA        USA      94080        NA
# 2    25 Old Broad Street      Level 7               UK   EC2N 1HN      EMEA
# 3      100 Market Street    Suite 300    CA        USA      94080        NA
# 4   523 East 53rd Street      apt. 5A    NY        USA      10022        NA

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a DataFrame with all of the customer contacts (first and last names) along with details for each of the customers' order numbers, order dates, and statuses.

# %%
cur.execute("""SELECT *
            FROM customers
            JOIN orders
            USING(customerNumber)
            ORDER BY contactLastName ASC
            ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    customerNumber        customerName contactLastName contactFirstName  \
# 0             249  Amica Models & Co.         Accorti           Paolo
# 1             249  Amica Models & Co.         Accorti           Paolo
# 2             187      AV Stores, Co.        Ashworth           Rachel
# 3             187      AV Stores, Co.        Ashworth           Rachel
# 4             187      AV Stores, Co.        Ashworth           Rachel
#
#             phone         addressLine1 addressLine2        city state  \
# 0     011-4988555  Via Monte Bianco 34                   Torino
# 1     011-4988555  Via Monte Bianco 34                   Torino
# 2  (171) 555-1555    Fauntleroy Circus               Manchester
# 3  (171) 555-1555    Fauntleroy Circus               Manchester
# 4  (171) 555-1555    Fauntleroy Circus               Manchester
#
#   postalCode country  salesRepEmployeeNumber  creditLimit  orderNumber  \
# 0      10100   Italy                    1401       113000        10280
# 1      10100   Italy                    1401       113000        10293
# 2    EC2 5NT      UK                    1501       136800        10110
# 3    EC2 5NT      UK                    1501       136800        10306
# 4    EC2 5NT      UK                    1501       136800        10332
#
#     orderDate requiredDate shippedDate   status comments
# 0  2004-08-17   2004-08-27  2004-08-19  Shipped
# 1  2004-09-09   2004-09-18  2004-09-14  Shipped
# 2  2003-03-18   2003-03-24  2003-03-20  Shipped
# 3  2004-10-14   2004-10-21  2004-10-17  Shipped
# 4  2004-11-17   2004-11-25  2004-11-18  Shipped

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a DataFrame with all of the customer contacts (first and last names) along with details for each of the customers' payment amounts and date of payment. Sort these results in descending order by the payment amount.

# %%
cur.execute("""SELECT *
            FROM customers
            JOIN payments
            USING(customerNumber)
            ORDER BY amount DESC
            ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    customerNumber                  customerName contactLastName  \
# 0             141        Euro+ Shopping Channel          Freyre
# 1             141        Euro+ Shopping Channel          Freyre
# 2             124  Mini Gifts Distributors Ltd.          Nelson
# 3             148       Dragon Souveniers, Ltd.       Natividad
# 4             124  Mini Gifts Distributors Ltd.          Nelson
#
#   contactFirstName           phone        addressLine1  \
# 0           Diego   (91) 555 94 44  C/ Moralzarzal, 86
# 1           Diego   (91) 555 94 44  C/ Moralzarzal, 86
# 2            Susan      4155551450     5677 Strong St.
# 3             Eric    +65 221 7555          Bronz Sok.
# 4            Susan      4155551450     5677 Strong St.
#
#                addressLine2        city state postalCode    country  \
# 0                                Madrid            28034      Spain
# 1                                Madrid            28034      Spain
# 2                            San Rafael    CA      97562        USA
# 3  Bronz Apt. 3/6 Tesvikiye   Singapore           079903  Singapore
# 4                            San Rafael    CA      97562        USA
#
#    salesRepEmployeeNumber  creditLimit checkNumber paymentDate     amount
# 0                    1370       227600    JE105477  2005-03-18  120166.58
# 1                    1370       227600     ID10962  2004-12-31  116208.40
# 2                    1165       210500    KI131716  2003-08-15  111654.40
# 3                    1621       103800    KM172879  2003-12-26  105743.00
# 4                    1165       210500    AE215433  2005-03-05  101244.59

# %% [markdown]
# ## Orders, Order details, and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a DataFrame with all of the customer contacts (first and last names) along with the product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# > Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries that can make complex queries such as this much simpler!

# %%
cur.execute("""SELECT *
            FROM customers c
            JOIN orders o
            USING(customerNumber)
            JOIN orderdetails od
            USING(orderNumber)
            JOIN products p
            USING(productCode)
            ORDER BY orderDate DESC
            ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#    customerNumber       customerName contactLastName contactFirstName  \
# 0             119  La Rochelle Gifts         Labrune          Janine
# 1             119  La Rochelle Gifts         Labrune          Janine
# 2             119  La Rochelle Gifts         Labrune          Janine
# 3             119  La Rochelle Gifts         Labrune          Janine
# 4             119  La Rochelle Gifts         Labrune          Janine
#
#         phone                  addressLine1 addressLine2    city state  \
# 0  40.67.8555  67, rue des Cinquante Otages               Nantes
# 1  40.67.8555  67, rue des Cinquante Otages               Nantes
# 2  40.67.8555  67, rue des Cinquante Otages               Nantes
# 3  40.67.8555  67, rue des Cinquante Otages               Nantes
# 4  40.67.8555  67, rue des Cinquante Otages               Nantes
#
#   postalCode  ... priceEach  orderLineNumber                     productName  \
# 0      44000  ...    131.49               12          1962 LanciaA Delta 16V
# 1      44000  ...     95.99                4               1957 Chevy Pickup
# 2      44000  ...    147.36                3  1998 Chrysler Plymouth Prowler
# 3      44000  ...    117.82                7          1964 Mercedes Tour Bus
# 4      44000  ...     48.62               10           1926 Ford Fire Engine
#
#         productLine productScale             productVendor  \
# 0      Classic Cars         1:10       Second Gear Diecast
# 1  Trucks and Buses         1:12             Exoto Designs
# 2      Classic Cars         1:18      Gearbox Collectibles
# 3  Trucks and Buses         1:18      Unimax Art Galleries
# 4  Trucks and Buses         1:18  Carousel DieCast Legends
#
#                                   productDescription quantityInStock buyPrice  \
# 0  Features include: Turnable front wheels; steer...            6791   103.42
# 1  1:12 scale die-cast about 20" long Hood opens,...            6125    55.70
# 2  Turnable front wheels; steering function; deta...            4724   101.51
# 3  Exact replica. 100+ parts. working steering sy...            8258    74.86
# 4  Gleaming red handsome appearance. Everything i...            2018    24.92
#
#      MSRP
# 0  147.74
# 1  118.50
# 2  163.73
# 3  122.73
# 4   60.77
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge of one-to-many and many-to-many relationships!
